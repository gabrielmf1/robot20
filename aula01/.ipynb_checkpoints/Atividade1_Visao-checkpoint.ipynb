# %% [markdown]
# # Entregável 1 - visão computacional

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print("OpenCV Version : %s " % cv2.__version__)
# Out:
# OpenCV Version : 4.2.0

# %% [markdown]
# # Equalização de histograma

# %%
rintin = cv2.imread("RinTinTin.jpg")

# %%
rintin.shape
# Out:
# (240, 320, 3)

# %%
rintin_gray = cv2.cvtColor(rintin, cv2.COLOR_RGB2GRAY)

# %%
rintin_gray.shape
# Out:
# (240, 320)

# %%
plt.imshow(rintin_gray, cmap="Greys_r", vmin=0, vmax=255)

# %%
hist,bins = np.histogram(rintin_gray.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Atividade 1
#
# Realize as seguintes atividades:
#
# 1. O histograma fornecido aproveita bem as faixas de cores?
# 2. Crie uma imagem derivada da imagem fornecida que use melhor a faixa dinâmica, ou seja, tenha o valor dos seus pixels distribuídos entre `0` e `255`.
# 3. Plote a imagem pedida

# %% [markdown]
# R1: Não pois o intervalo usado não é o adequado (0,255)

# %%
rintin_saida = rintin_gray.copy()
m = 255/50
c = m*8
for i in range(rintin_gray.shape[0]):
    for j in range(rintin_gray.shape[1]):
        rintin_saida[i][j] = rintin_gray[i][j]*m - c
        
plt.imshow(rintin_saida, cmap="Greys_r", vmin=0, vmax=255)
plt.show()

# %% [markdown]
# ## Atividade 2

# %% [markdown]
# Leia com a OpenCV a figura abaixo:
#
# ![](cena_canto_sala.jpg)
#
# Separe os canais  R e B das imagens e analise seus histogramas.
#
# 1. A partir dos canais R e B e da análise do histograma é possível identificar a caixa vermelha e o creeper azul?
#
# 1. Crie uma imagem numpy em que somente os pixels da caixa vermelha estão brancos e faça seu plot aqui. Você vai precisar usar manipulação de canais RGB. Use o [ExemploFor.ipynb](ExemploFor.ipynb) .

# %%
atv2 = cv2.imread('cena_canto_sala.jpg')
atv2_rgb = cv2.cvtColor(atv2, cv2.COLOR_BGR2RGB)

# %%
atv2_r = atv2_rgb[:,:,0]
atv2_b = atv2_rgb[:,:,2]

plt.imshow(atv2_r, cmap='Greys_r')

# %%
plt.imshow(atv2_b, cmap='Greys_r')

# %%
def histograma(img,cor):   
    hist,bins = np.histogram(img.flatten(),256,[0,256])
    plt.hist(img.flatten(),256,[0,256], color = cor)
    plt.xlim([0,256])
    plt.show()

# %%
histograma(atv2_r,'r')

# %%
histograma(atv2_b,'b')

# %% [markdown]
# R1: Sim, pois os picos apresentados no histograma representam as paredes e o chão devido a grande quantidade de pixels semelhantes na imagem. Enquanto que a caixa laranja e o creeper azul apresentam poucos pixels, em seus canais rgb eles apresentam uma concentração mais perto do valor 255 de sua cor. Assim podemos identificá-los observando a parte mais a direita do histograma.

# %%
atv2_copia = atv2_rgb.copy()
for i in range(atv2_rgb.shape[0]):
    for j in range(atv2_rgb.shape[1]):
        if atv2_rgb[i][j][0] > 200 and atv2_rgb[i][j][1] >75 and atv2_rgb[i][j][2] < 30:
            atv2_copia[i][j] = 255
        else:
            atv2_copia[i][j] = 0

# %%
plt.imshow(atv2_copia, cmap='Greys_r')

# %% [markdown]
# # Atividade 3
#
#
# Abra a imagem `hall_box_battery_atividade3.png`  e a converta para tons de cinza de `0` a `255`.
#
# Forneça como saída uma uma cópia da imagem  em que cada pixel  recebe o módulo da subtração entre o pixel que vem depois e o que vem antes dele (na horizontal).
#
# Obs.: O conceito de *antes* e *depois* pode ser na horizontal ou na vertical
#
# Apresente a imagem resultado, deve ficar parecida com a imagem `gabarito_atividade_3.png`.
#
# <img src="gabarito_atividade_3.png" width=400>

# %%
atv3 = cv2.imread('hall_box_battery_atividade3.png')
atv3_gray = cv2.cvtColor(atv3, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(atv3_gray, cmap='Greys_r')

# %%
atv3_gray.shape
# Out:
# (576, 1024)

# %%
atv3_copia = atv3_gray.copy()
for i in range(atv3_gray.shape[0]):
    for j in range(atv3_gray.shape[1]):
        if i == 0 or i == 575:
            pass
        else:
            atv3_copia[i][j] = abs(int(atv3_gray[i+1][j]) - int(atv3_gray[i-1][j]))

# %%
plt.imshow(atv3_copia, cmap='Greys_r', vmin=0, vmax=255)
